# %%
import pandas as pd
import matplotlib.pyplot as plt
csi_matrix = pd.DataFrame(pd.read_csv(f"files_csv/fall_down/fall_down_2.csv"))
plt.matshow(csi_matrix.corr())
plt.title("fall_down_2.csv")
plt.show()

# %%
csi_matrix = pd.DataFrame(pd.read_csv(f"files_csv/hand_circle/hand_circle_2.csv"))
plt.matshow(csi_matrix.corr())
plt.title("hand_circle_2.csv")
plt.show()

# %%
csi_matrix = pd.DataFrame(pd.read_csv(f"files_csv/hand_right/hand_right_2.csv"))
plt.matshow(csi_matrix.corr())
plt.title("hand_right_2.csv")
plt.show()

# %%
csi_matrix = pd.DataFrame(pd.read_csv(f"files_csv/nothing/nothing_3.csv"))
plt.matshow(csi_matrix.corr())
plt.title("nothing_3.csv")
plt.show()

# %%
csi_matrix = pd.DataFrame(pd.read_csv(f"files_csv/smoking/smoking_2.csv"))
plt.matshow(csi_matrix.corr())
plt.title("smoking_2.csv")
plt.show()

# %%
csi_matrix = pd.DataFrame(pd.read_csv(f"files_csv/walking_along/walking_along_2.csv"))
plt.matshow(csi_matrix.corr())
plt.title("walking_along_2.csv")
plt.show()

# %%
csi_matrix = pd.DataFrame(pd.read_csv(f"files_csv/walking_prpendicular/walking_prpendicular_2.csv"))
plt.matshow(csi_matrix.corr())
plt.title("walking_prpendicular_2.csv")
plt.show()
