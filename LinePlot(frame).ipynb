# %%
import pandas as pd
csi_matrix = pd.DataFrame(pd.read_csv("files_csv/fall_down/fall_down_1.csv"))
csi_matrix.iloc[0].plot.line(legend=False)
# Out:
# <AxesSubplot:>

# %%
for i in range(78):
    csi_matrix.iloc[i].plot.line(legend=False)

# %%
csi_matrix = pd.DataFrame(pd.read_csv("files_csv/hand_circle/hand_circle_1.csv"))
csi_matrix.iloc[0].plot.line(legend=False)
# Out:
# <AxesSubplot:>

# %%
csi_matrix = pd.DataFrame(pd.read_csv("files_csv/hand_right/hand_right_1.csv"))
csi_matrix.iloc[0].plot.line(legend=False)
# Out:
# <AxesSubplot:>

# %%
csi_matrix = pd.DataFrame(pd.read_csv("files_csv/nothing/nothing_3.csv"))
csi_matrix.iloc[0].plot.line(legend=False)
# Out:
# <AxesSubplot:>

# %%
csi_matrix = pd.DataFrame(pd.read_csv("files_csv/smoking/smoking_1.csv"))
csi_matrix.iloc[0].plot.line(legend=False)
# Out:
# <AxesSubplot:>

# %%
csi_matrix = pd.DataFrame(pd.read_csv("files_csv/walking_along/walking_along_1.csv"))
csi_matrix.iloc[0].plot.line(legend=False)
# Out:
# <AxesSubplot:>

# %%
csi_matrix = pd.DataFrame(pd.read_csv("files_csv/walking_prpendicular/walking_prpendicular_1.csv"))
csi_matrix.iloc[0].plot.line(legend=False)
# Out:
# <AxesSubplot:>
