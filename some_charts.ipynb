# %%
import matplotlib.pyplot as plt
import pandas as pd
from CSIKit.tools.batch_graph import BatchGraph
import seaborn as sns

# %% [markdown]
# ## Line_plot_all

# %%
csi_matrix = pd.DataFrame(pd.read_csv("csv_files_one_move/falldown_one_move/falldown_1.csv"))
packet = csi_matrix
packages = []
for i in range (1,len(csi_matrix)):

    csi_matrix.iloc[i][1:].plot.line(legend=False)

# packages.plot.line(legend=False)

# %%
# new_list = [csi_matrix.iloc[3],m]
plt.matshow(csi_matrix.corr())
plt.show()

# %%
corr = csi_matrix.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True)

# %%
bg = BatchGraph("pcap_files_one_move/walking_along_one_move/walking_along_2.pcap")
bg.heatmap()
