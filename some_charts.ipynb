# %%
import matplotlib.pyplot as plt
import pandas as pd
from CSIKit.tools.batch_graph import BatchGraph
import seaborn as sns
from sklearn.decomposition import PCA

# %% [markdown]
# ## Line_plot_all

# %%
csi_matrix = pd.DataFrame(pd.read_csv("csv_files/falldown/Falldown_1.csv"))
packages = []
# for i in range (1,len(csi_matrix)):

csi_matrix.iloc[1][1:].plot.line(legend=False)

# packages.plot.line(legend=False)
# Out:
# <AxesSubplot:>

# %%
# new_list = [csi_matrix.iloc[3],m]
plt.matshow(csi_matrix.corr())
plt.show()

# %%
corr = csi_matrix.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True)

# %%
bg = BatchGraph("pcap_files/falldown/Falldown_1.pcap")
bg.heatmap()
