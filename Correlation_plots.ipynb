# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# %%
# main_dir = os.listdir("csv_files")
# for ind, i in enumerate(main_dir):
#     files_list = os.listdir(f"csv_files/{i}")
#     for j in files_list:
csi_matrix = pd.DataFrame(pd.read_csv(f"csv_files/walk/walk_1591628635.csv"))
plt.matshow(csi_matrix.corr())
plt.title("walk_1591628635.csv")
plt.show()
