# %%
import numpy as np
import pandas as pd
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt

# %%
def import_from_csv(dir,actions=[]):
    filenames = [f for f in listdir(dir)
        if isfile(join(dir, f))]
    res={}
    for f in filenames:
        a="_".join(f.split("_")[:-1])
        if (a in actions) or not actions:
            df=pd.read_csv(join(dir, f))
            if a not in res.keys():
                res[a]=[]
            res[a].append(df)
    return res

# %%
actions=["walk","nothing"]
cwt_train=import_from_csv('cwt_train/',actions)

for a in cwt_train.keys():
    print(a, len(cwt_train[a]))
cwt_train["walk"][-1]
# Out:
# nothing 70
# walk 68
#              0          1          2         3          4          5  \
# 0     3.834924   2.633517  -4.070453 -6.315658  -4.060870   1.914876
# 1     4.493266   0.093741  -6.032467 -6.404798  -2.195393   2.911452
# 2     3.639862  -2.965457  -7.331440 -5.659520   0.279009   1.557655
# 3     4.633567   1.190996  -5.872021 -7.778529  -3.724128   1.769928
# 4     4.072619  -2.197825  -7.984155 -7.136019  -1.275650   1.142213
# ..         ...        ...        ...       ...        ...        ...
# 100  14.835715  -1.389801  11.494333  4.810109 -13.343586  26.920148
# 101   4.051753   4.301376  14.471103 -4.732804  10.443677   4.052579
# 102   0.141084  16.833517  10.524034  1.851827   7.559256   8.958940
# 103  -4.634373  12.970588   4.186156  6.965902  14.751576   6.067012
# 104  25.036663 -10.936047  23.328416 -4.064524  19.146702   1.032457
#
#              6          7          8          9  ...        332        333  \
# 0     0.859310  -5.129967  13.954263  14.153317  ...  -1.119299   3.146940
# 1    -2.689602   0.821397  19.718777   4.375964  ...   1.666782   0.699380
# 2    -3.706306  10.413898  18.006274  -5.325499  ...   2.527846  -2.790906
# 3    -1.113910   0.754031  18.084493   9.805259  ...  -0.016487   0.991597
# 4    -1.731946   9.467764  18.802651  -0.533179  ...   1.250168  -2.565204
# ..         ...        ...        ...        ...  ...        ...        ...
# 100   3.424759  -6.915234  17.249584   5.168083  ...  -5.919818  -9.774950
# 101   7.219731  16.474634   0.807890   4.361391  ...  -9.683698  -5.706734
# 102   6.094383  -2.491754  16.667398  12.357155  ... -20.445790  -5.580979
# 103   7.294264  -0.169676  22.287577  -4.471387  ...   2.734860 -19.823257
# 104  11.589995   5.649677  13.147386  11.732401  ... -18.689778  -9.550476
#
#            334        335        336        337        338        339  \
# 0    -4.056125  -9.711186  -8.797357  15.179512  17.945278  -4.614415
# 1    -7.144427 -11.851075  -0.906338  22.194168   9.817212  -7.911877
# 2   -10.462499 -10.542119  10.613184  22.086365   1.525181  -9.414384
# 3    -7.021024 -12.774183  -3.327095  20.264610  15.810800  -5.046976
# 4   -11.204385 -11.396182   8.109514  23.177764   7.109282  -8.736992
# ..         ...        ...        ...        ...        ...        ...
# 100  -1.935232 -14.818449  -5.762132  -6.070006 -17.948174  -1.633129
# 101 -10.987988  -4.588175 -12.659435  -9.435660  -4.580184 -10.027319
# 102 -13.757367  -0.962847  -6.807521 -25.743605   7.621756 -18.548208
# 103  -7.174273  -5.672925 -18.708337  -5.625089 -10.435553  -3.961941
# 104 -17.651008  -2.979823 -18.916184  -0.890829 -16.033925  -2.729805
#
#            340        341
#
#            308        309
# 0    -6.410320  -3.560394
# 1    -6.526659  -1.843275
# 2    -5.419258  -0.683067
# 3    -7.498687  -3.671011
# 4    -6.922282  -2.152197
# ..         ...        ...
# 100   7.462831   9.506750
# 101   5.800516  14.030028
# 102   5.658777   7.707968
# 103 -13.173040  30.645117
# 104  -0.355669  16.023739
#
# [105 rows x 310 columns]

# %%
plt.figure(figsize=(30,4))
counts_for_lengths={}

for a in actions:
    plot_x=[]
    plot_y=[]
    for df in cwt_train[a]:
        x=df.shape[1]
        if x not in counts_for_lengths.keys():
            counts_for_lengths[x]=1
            y=1
        else:
            y=counts_for_lengths[x]+1
            counts_for_lengths[x]+=1
        plot_x.append(x)
        plot_y.append(y)
    print(a)
    plt.scatter(plot_x,plot_y,label=a,s=8)

print(sum(counts_for_lengths.values()))
plt.legend()
plt.show()
# Out:
# walk
# nothing
# 138

# %%
#only 300+

plt.figure(figsize=(30,4))
counts_for_lengths={}

for a in actions:
    plot_x=[]
    plot_y=[]
    for df in cwt_train[a]:
        x=df.shape[1]
        if x<300:
            continue
        if x not in counts_for_lengths.keys():
            counts_for_lengths[x]=1
            y=1
        else:
            y=counts_for_lengths[x]+1
            counts_for_lengths[x]+=1
        plot_x.append(x)
        plot_y.append(y)
    print(a)
    plt.scatter(plot_x,plot_y,label=a,s=8)

print(sum(counts_for_lengths.values()))
plt.legend()
plt.show()
# Out:
# walk
# nothing
# 125

# %% [markdown]
# Adding cuts from "nothing" to get same shapes

# %%
def to_same_sizes(data,l,r,filler):
    res={}
    for a in data.keys():
        res[a]=[]
        for df in data[a]:
            if df.shape[1]==r:
                #print(1, df.shape)
                res[a].append(df)
                continue
            if df.shape[1]>r:
                df_=df.iloc[:,:r]
                #print(2, df_.shape)
                res[a].append(df_)
                continue
            if df.shape[1]<r and df.shape[1]>l:
                df_=pd.concat( [ df.iloc[:,:r], filler.iloc[:,:(r-df.shape[1])] ] ,axis=1)
                #print(3, df_.shape)
                res[a].append(df_)

    return res

# %%
l=300
r=357
nothing_df=cwt_train["nothing"][-1]
sh1,sh2=nothing_df.shape
print(sh1,sh2)
cwt_train["nothing"]=cwt_train["nothing"][:-1]

trainDct=to_same_sizes(cwt_train,l,r,nothing_df)
testDct=to_same_sizes(cwt_test,l,r,nothing_df)

for a in actions:
    print(a, len(trainDct[a]),len(testDct[a]))
# Out:
# 105 340
# walk 64 22
# nothing 60 25

# %%
def to_one_df(data,action_dct):
    res=pd.DataFrame()
    for action in data.keys():
        for df in data[action]:
            row=(df.values).flatten()
            row=np.append(row,action_dct[action])
            res=res.append(pd.Series(row),ignore_index=True)
            print(res.shape)
    return res

# %%
action_dct={}
i=0
for a in trainDct.keys():
    action_dct[a]=i
    i+=1

train=to_one_df(trainDct,action_dct)
# Out:
# (1, 37486)
# (2, 37486)
# (3, 37486)
# (4, 37486)
# (5, 37486)
# (6, 37486)
# (7, 37486)
# (8, 37486)
# (9, 37486)
# (10, 37486)
# (11, 37486)
# (12, 37486)
# (13, 37486)
# (14, 37486)
# 2    -5.331127   0.142893   5.494643   2.284959  ...   4.926586   8.189310
# 3    -3.750193  -3.043784   5.602923   1.803921  ...  -8.025144  10.543186
# 4     3.642594   2.021829   1.294924  -0.359010  ...  -3.461470   5.561665
# ..         ...        ...        ...        ...  ...        ...        ...
# 119  -4.543668 -12.873768  13.235782  13.872281  ...  -7.290766  -6.864826
# 120   0.529819   8.950941  -7.104644 -25.214728  ...  -0.714746  -9.611848
# 121   0.594497 -11.575593 -12.696114  23.679861  ...  -2.953646  -0.714746
# 122  -9.179705  -7.485404  14.737468  16.725546  ...  -8.513062  -2.953646
# 123   0.859310  -5.129967  13.954263  14.153317  ...  -8.583891  -6.599671
#
#          37478     37479      37480      37481      37482      37483  \
# 0    -1.612906  8.127444  17.522760  -0.236398  14.177418   4.394096
# 1   -19.745557  3.782146 -20.024390   3.052740  -6.126187 -11.305168
# 2    17.122570  2.449319   4.908302  10.835084   6.452215  13.709064
# 3    -5.241138  8.026553  -0.412282   5.772346   7.012548  -2.093491
# 4    -2.093491 -6.257948  -6.294858  -3.185036  -7.290766  -6.864826
# ..         ...       ...        ...        ...        ...        ...
# 119  -8.583891 -6.599671  -8.513062  -2.953646  -0.714746  -9.611848
# 120  -7.845841 -2.577865  -8.349053  -4.343331 -11.773422  -0.927389
# 121  -9.611848 -7.845841  -2.577865  -8.349053  -4.343331 -11.773422
# 122  -0.714746 -9.611848  -7.845841  -2.577865  -8.349053  -4.343331
# 123  -8.513062 -2.953646  -0.714746  -9.611848  -7.845841  -2.577865
#
#          37484  37485
# 0     7.918568    0.0
# 1    -4.729009    0.0
# 2     4.154442    0.0
# 3    -6.257948    0.0
# 4    -8.583891    0.0
# ..         ...    ...
# 119  -7.845841    1.0
# 120 -19.745557    1.0
# 121  -0.927389    1.0
# 122 -11.773422    1.0
# 123  -8.349053    1.0
#
# [124 rows x 37486 columns]

# %%
test=to_one_df(testDct,action_dct)
test
# Out:
# (1, 37486)
# (2, 37486)
# (3, 37486)
# (4, 37486)
# (5, 37486)
# (6, 37486)
# (7, 37486)
# (8, 37486)
# (9, 37486)
# (10, 37486)
# (11, 37486)
# (12, 37486)
# (13, 37486)
# (14, 37486)
# (15, 37486)
# (16, 37486)
# (17, 37486)
# (18, 37486)
# (19, 37486)
# (20, 37486)
# (21, 37486)
# (22, 37486)
# (23, 37486)
# (24, 37486)
# (25, 37486)
# (26, 37486)
# (27, 37486)
# (28, 37486)
# (29, 37486)
# (30, 37486)
# (31, 37486)
# (32, 37486)
# (33, 37486)
# (34, 37486)
# (35, 37486)
# (36, 37486)
# (37, 37486)
# (38, 37486)
# (39, 37486)
# (40, 37486)
# (41, 37486)
# (42, 37486)
# (43, 37486)
# (44, 37486)
# (45, 37486)
# (46, 37486)
# (47, 37486)
#         0          1          2          3          4          5      \
# 0   -4.976249  12.455507   7.977901  -8.037831  -0.830780  -1.441641
# 1    3.759347  -2.050424  -5.861265  -3.862378 -12.072716  16.146415
# 2    1.611193   0.977430  -5.036216  -6.157202  -3.130461  -3.176008
# 3   -0.444069  -9.509568   1.695420   9.868954  -5.101841 -20.354537
-6.864826  -8.583891  -6.599671  -8.513062  -2.953646  -0.714746
# 37  31.908698  -2.093491  -6.257948  -6.294858  -3.185036  -7.290766
# 38  -6.864826  -8.583891  -6.599671  -8.513062  -2.953646  -0.714746
# 39  -7.845841  -2.577865  -8.349053  -4.343331 -11.773422  -0.927389
# 40  -8.513062  -2.953646  -0.714746  -9.611848  -7.845841  -2.577865
# 41  -6.599671  -8.513062  -2.953646  -0.714746  -9.611848  -7.845841
# 42  -0.714746  -9.611848  -7.845841  -2.577865  -8.349053  -4.343331
# 43  -8.349053  -4.343331 -11.773422  -0.927389 -19.745557   3.782146
# 44  -8.349053  -4.343331 -11.773422  -0.927389 -19.745557   3.782146
# 45  -0.714746  -9.611848  -7.845841  -2.577865  -8.349053  -4.343331
# 46  -2.219060 -20.607129   2.053259 -10.652743 -11.554636  -3.184193
#
#         37484  37485
# 0  -20.024390    0.0
# 1   -4.343331    0.0
# 2   -0.927389    0.0
# 3   -7.845841    0.0
# 4   -7.845841    0.0
# 5   -0.927389    0.0
# 6   -0.714746    0.0
# 7  -13.213651    0.0
# 8   -6.126187    0.0
# 9  -11.773422    0.0
# 10  -2.577865    0.0
# 11  -9.611848    0.0
# 12 -30.849360    0.0
# 13 -11.773422    0.0
# 14 -11.305168    0.0
# 15 -11.773422    0.0
# 16  -7.845841    0.0
# 17 -19.745557    0.0
# 18  -4.343331    0.0
# 19  -7.290766    0.0
# 20  -8.349053    0.0
# 21 -11.773422    0.0
# 22  -2.953646    0.0
# 23  -8.583891    0.0
# 24  -4.343331    0.0
# 25  -8.583891    1.0
# 26  -4.343331    1.0
# 27  -0.927389    1.0
# 28 -20.024390    1.0
# 29  -0.714746    1.0
# 30  -9.611848    1.0
# 31  -0.927389    1.0
# 32  -6.126187    1.0
# 33  -5.335969    1.0
# 34  -0.714746    1.0
# 35   3.052740    1.0
# 36  -9.611848    1.0
# 37  -6.864826    1.0
# 38  -9.611848    1.0
# 39 -19.745557    1.0
# 40  -8.349053    1.0
# 41  -2.577865    1.0
# 42 -11.773422    1.0
# 43 -20.024390    1.0
# 44 -20.024390    1.0
# 45 -11.773422    1.0
# 46 -11.307290    1.0
#
# [47 rows x 37486 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score

# %%
test=test.rename(columns={test.columns[-1]: "target"})
train=train.rename(columns={train.columns[-1]: "target"})

# %%
train_df=train.drop(columns=["target"])
train_target=train["target"]
test_df=test.drop(columns=["target"])
test_target=test["target"]

# %%
rf = RandomForestClassifier(oob_score=True, random_state=1, n_jobs=-1)

# %%
param_grid = { "criterion" : ["entropy"],
               "min_samples_leaf" : [1, 5, 10],
               "min_samples_split" : [2, 4, 10],
               "max_depth": [6, 8, 10],
               "n_estimators": [50, 100, 200]}
gs = GridSearchCV(estimator=rf, param_grid=param_grid, scoring='accuracy',
                  cv=3, verbose=10)
gs = gs.fit(train_df, train_target)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [CV 1/3; 1/81] START criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/3; 1/81] END criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  26.7s
# [CV 2/3; 1/81] START criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/3; 1/81] END criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   4.9s
# [CV 3/3; 1/81] START criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 3/3; 1/81] END criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   5.4s
# [CV 1/3; 2/81] START criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/3; 2/81] END criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.9s
# [CV 2/3; 2/81] START criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/3; 2/81] END criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   6.3s
# [CV 3/3; 2/81] START criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/3; 2/81] END criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   6.5s
# [CV 1/3; 3/81] START criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 1/3; 3/81] END criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  10.2s
# [CV 2/3; 3/81] START criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 2/3; 3/81] END criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.8s
# [CV 3/3; 3/81] START criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 3/3; 3/81] END criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  10.2s
# [CV 1/3; 4/81] START criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=4, n_estimators=50
# [CV 1/3; 4/81] END criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   3.7s
# [CV 2/3; 4/81] START criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=4, n_estimators=50
# [CV 2/3; 4/81] END criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   4.3s
# [CV 3/3; 4/81] START criterion=entropy, max_depth=6, min_samples_leaf=1, min_samples_split=4, n_estimators=50
# [CV
81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=50
# [CV 3/3; 58/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   4.1s
# [CV 1/3; 59/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV 1/3; 59/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   6.6s
# [CV 2/3; 59/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV 2/3; 59/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   5.9s
# [CV 3/3; 59/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV 3/3; 59/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   6.1s
# [CV 1/3; 60/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV 1/3; 60/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  10.5s
# [CV 2/3; 60/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV 2/3; 60/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  10.3s
# [CV 3/3; 60/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV 3/3; 60/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  10.9s
# [CV 1/3; 61/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/3; 61/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV 2/3; 61/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/3; 61/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV 3/3; 61/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 3/3; 61/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   3.2s
# [CV 1/3; 62/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/3; 62/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.0s
# [CV 2/3; 62/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/3; 62/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.0s
# [CV 3/3; 62/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 3/3; 62/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   4.9s
# [CV 1/3; 63/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 1/3; 63/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   9.7s
# [CV 2/3; 63/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 2/3; 63/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  10.3s
# [CV 3/3; 63/81] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 3/3; 63/81] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  10.8s
# [CV 1/3; 64/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50
# [CV 1/3; 64/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   4.0s
# [CV 2/3; 64/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50
# [CV 2/3; 64/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   3.9s
# [CV 3/3; 64/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50
# [CV 3/3; 64/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   3.7s
# [CV 1/3; 65/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=100
# [CV 1/3; 65/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   6.2s
# [CV 2/3; 65/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=100
# [CV 2/3; 65/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   6.0s
# [CV 3/3; 65/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=100
# [CV 3/3; 65/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   6.8s
# [CV 1/3; 66/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=200
# [CV 1/3; 66/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  11.2s
# [CV 2/3; 66/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=200
# [CV 2/3; 66/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  11.4s
# [CV 3/3; 66/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=200
# [CV 3/3; 66/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  13.0s
# [CV 1/3; 67/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 1/3; 67/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=50; total time=   4.5s
# [CV 2/3; 67/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 2/3; 67/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=50; total time=   4.2s
# [CV 3/3; 67/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 3/3; 67/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=50; total time=   3.7s
# [CV 1/3; 68/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 1/3; 68/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   5.9s
# [CV 2/3; 68/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 2/3; 68/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   5.9s
# [CV 3/3; 68/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 3/3; 68/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   6.0s
# [CV 1/3; 69/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 1/3; 69/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=200; total time=  10.2s
# [CV 2/3; 69/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 2/3; 69/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=200; total time=   9.9s
# [CV 3/3; 69/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 3/3; 69/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=4, n_estimators=200; total time=   8.9s
# [CV 1/3; 70/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 1/3; 70/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   3.2s
# [CV 2/3; 70/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 2/3; 70/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   4.6s
# [CV 3/3; 70/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 3/3; 70/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   4.2s
# [CV 1/3; 71/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 1/3; 71/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   7.0s
# [CV 2/3; 71/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/3; 71/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   5.7s
# [CV 3/3; 71/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 3/3; 71/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   5.7s
# [CV 1/3; 72/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 1/3; 72/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   9.9s
# [CV 2/3; 72/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 2/3; 72/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  11.3s
# [CV 3/3; 72/81] START criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 3/3; 72/81] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  10.9s
# [CV 1/3; 73/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=50
# [CV 1/3; 73/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   3.9s
# [CV 2/3; 73/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=50
# [CV 2/3; 73/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   4.0s
# [CV 3/3; 73/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=50
# [CV 3/3; 73/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   3.9s
# [CV 1/3; 74/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=100
# [CV 1/3; 74/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   8.2s
# [CV 2/3; 74/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=100
# [CV 2/3; 74/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   6.3s
# [CV 3/3; 74/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=100
# [CV 3/3; 74/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=36.3min
# [CV 1/3; 75/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=200
# C:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\externals\loky\process_executor.py:688: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV 1/3; 75/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=  32.2s
# [CV 2/3; 75/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=200
# [CV 2/3; 75/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=  11.9s
# [CV 3/3; 75/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=200
# [CV 3/3; 75/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=  10.5s
# [CV 1/3; 76/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 1/3; 76/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=50; total time=   3.9s
# [CV 2/3; 76/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 2/3; 76/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=50; total time=   3.4s
# [CV 3/3; 76/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 3/3; 76/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=50; total time=   3.3s
# [CV 1/3; 77/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 1/3; 77/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=100; total time=   6.0s
# [CV 2/3; 77/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 2/3; 77/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=100; total time=   5.7s
# [CV 3/3; 77/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 3/3; 77/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=100; total time=   4.7s
# [CV 1/3; 78/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 1/3; 78/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   8.7s
# [CV 2/3; 78/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 2/3; 78/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   8.7s
# [CV 3/3; 78/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 3/3; 78/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   8.2s
# [CV 1/3; 79/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 1/3; 79/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.1s
# [CV 2/3; 79/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 2/3; 79/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.1s
# [CV 3/3; 79/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 3/3; 79/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.1s
# [CV 1/3; 80/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 1/3; 80/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   5.0s
# [CV 2/3; 80/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 2/3; 80/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   4.8s
# [CV 3/3; 80/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 3/3; 80/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   4.8s
# [CV 1/3; 81/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 1/3; 81/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   8.2s
# [CV 2/3; 81/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 2/3; 81/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   8.5s
# [CV 3/3; 81/81] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 3/3; 81/81] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   8.9s

# %%
print("train_best_score =",gs.best_score_)
print(gs.best_params_)

best_est = gs.best_estimator_

print("test_score =",best_est.score(test_df, test_target))
# Out:
# train_best_score = 0.6699574138598529
# {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# test_score = 0.574468085106383
