# %%
import pandas as pd

# %% [markdown]
# ## LINE PLOT ONE LINE

# %%
csi_matrix = pd.DataFrame(pd.read_csv("сsv_files/brushteeth/brushteeth_1591629178.csv"))
csi_matrix.iloc[0].plot.line(legend=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## LINE POT ALL LINES

# %%
for k in range (1,len(csi_matrix)):
    csi_matrix.iloc[k].plot.line(legend=False)
