# %%
from CSIKit.tools.batch_graph import BatchGraph
bg = BatchGraph("files_pcap/fall_down/fall_down_2.pcap")
bg.heatmap()

# %%
bg = BatchGraph("files_pcap/hand_circle/hand_circle_2.pcap")
bg.heatmap()

# %%
bg = BatchGraph("files_pcap/smoking/smoking_2.pcap")
bg.heatmap()

# %%
bg = BatchGraph("files_pcap/walking_along/walking_along_2.pcap")
bg.heatmap()

# %%
bg = BatchGraph("files_pcap/walking_prpendicular/walking_prpendicular_2.pcap")
bg.heatmap()

# %%
bg = BatchGraph("files_pcap/nothing/nothing_3.pcap")
bg.heatmap()
