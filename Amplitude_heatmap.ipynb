# %%
from CSIKit.tools.batch_graph import BatchGraph
bg = BatchGraph("files_pcap/fall_down/fall_down_1.pcap")
bg.heatmap()

# %%
bg = BatchGraph("files_pcap/hand_circle/hand_circle_1.pcap")
bg.heatmap()

# %%
bg = BatchGraph("files_pcap/hand_right/hand_right_1.pcap")
bg.heatmap()

# %%
bg = BatchGraph("files_pcap/nothing/nothing_3.pcap")
bg.heatmap()

# %%
bg = BatchGraph("files_pcap/smoking/smoking_1.pcap")
bg.heatmap()

# %%
bg = BatchGraph("files_pcap/walking_along/walking_along_1.pcap")
bg.heatmap()

# %%
bg = BatchGraph("files_pcap/walking_prpendicular/walking_prpendicular_1.pcap")
bg.heatmap()
