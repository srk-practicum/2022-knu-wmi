# %%
import pywt
import pywt.data

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
train_pca_list = []
train_pca_list_name = []
filenames = ['brushteeth_', 'cook_', 'drink_', 'getintobed_', 'nothing_', 'sitdown_chair_', 'sitdown_sofa_', 'sleeping_', 
             'standup_chair_', 'standup_sofa_', 'walk_', 'washingdishes_']

for ind, file in enumerate(filenames):
    temp = []
    temp_name = []
    for i in range(25):
        df = pd.read_csv(fr'training_pca_csv/{file} ({i+1}).csv')
        temp.append(df)
        temp_name.append(fr'training_pca_csv/{file} ({i+1}).csv')
    train_pca_list.append(temp)
    train_pca_list_name.append(temp_name)

# %%
for temp in train_pca_list_name:
    print(temp)
    print('\n\n')
# Out:
# ['training_pca_csv/brushteeth_ (1).csv', 'training_pca_csv/brushteeth_ (2).csv', 'training_pca_csv/brushteeth_ (3).csv', 'training_pca_csv/brushteeth_ (4).csv', 'training_pca_csv/brushteeth_ (5).csv', 'training_pca_csv/brushteeth_ (6).csv', 'training_pca_csv/brushteeth_ (7).csv', 'training_pca_csv/brushteeth_ (8).csv', 'training_pca_csv/brushteeth_ (9).csv', 'training_pca_csv/brushteeth_ (10).csv', 'training_pca_csv/brushteeth_ (11).csv', 'training_pca_csv/brushteeth_ (12).csv', 'training_pca_csv/brushteeth_ (13).csv', 'training_pca_csv/brushteeth_ (14).csv', 'training_pca_csv/brushteeth_ (15).csv', 'training_pca_csv/brushteeth_ (16).csv', 'training_pca_csv/brushteeth_ (17).csv', 'training_pca_csv/brushteeth_ (18).csv', 'training_pca_csv/brushteeth_ (19).csv', 'training_pca_csv/brushteeth_ (20).csv', 'training_pca_csv/brushteeth_ (21).csv', 'training_pca_csv/brushteeth_ (22).csv', 'training_pca_csv/brushteeth_ (23).csv', 'training_pca_csv/brushteeth_ (24).csv', 'training_pca_csv/brushteeth_ (25).csv']
#
#
#
# ['training_pca_csv/cook_ (1).csv', 'training_pca_csv/cook_ (2).csv', 'training_pca_csv/cook_ (3).csv', 'training_pca_csv/cook_ (4).csv', 'training_pca_csv/cook_ (5).csv', 'training_pca_csv/cook_ (6).csv', 'training_pca_csv/cook_ (7).csv', 'training_pca_csv/cook_ (8).csv', 'training_pca_csv/cook_ (9).csv', 'training_pca_csv/cook_ (10).csv', 'training_pca_csv/cook_ (11).csv', 'training_pca_csv/cook_ (12).csv', 'training_pca_csv/cook_ (13).csv', 'training_pca_csv/cook_ (14).csv', 'training_pca_csv/cook_ (15).csv', 'training_pca_csv/cook_ (16).csv', 'training_pca_csv/cook_ (17).csv', 'training_pca_csv/cook_ (18).csv', 'training_pca_csv/cook_ (19).csv', 'training_pca_csv/cook_ (20).csv', 'training_pca_csv/cook_ (21).csv', 'training_pca_csv/cook_ (22).csv', 'training_pca_csv/cook_ (23).csv', 'training_pca_csv/cook_ (24).csv', 'training_pca_csv/cook_ (25).csv']
#
#
#
# ['training_pca_csv/drink_ (1).csv', 'training_pca_csv/drink_ (2).csv', 'training_pca_csv/drink_ (3).csv', 'training_pca_csv/drink_ (4).csv', 'training_pca_csv/drink_ (5).csv', 'training_pca_csv/drink_ (6).csv', 'training_pca_csv/drink_ (7).csv', 'training_pca_csv/drink_ (8).csv', 'training_pca_csv/drink_ (9).csv', 'training_pca_csv/drink_ (10).csv', 'training_pca_csv/drink_ (11).csv', 'training_pca_csv/drink_ (12).csv', 'training_pca_csv/drink_ (13).csv', 'training_pca_csv/drink_ (14).csv', 'training_pca_csv/drink_ (15).csv', 'training_pca_csv/drink_ (16).csv', 'training_pca_csv/drink_ (17).csv', 'training_pca_csv/drink_ (18).csv', 'training_pca_csv/drink_ (19).csv', 'training_pca_csv/drink_ (20).csv', 'training_pca_csv/drink_ (21).csv', 'training_pca_csv/drink_ (22).csv', 'training_pca_csv/drink_ (23).csv', 'training_pca_csv/drink_ (24).csv', 'training_pca_csv/drink_ (25).csv']
#
#
#
# ['training_pca_csv/getintobed_ (1).csv', 'training_pca_csv/getintobed_ (2).csv', 'training_pca_csv/getintobed_ (3).csv', 'training_pca_csv/getintobed_ (4).csv', 'training_pca_csv/getintobed_ (5).csv', 'training_pca_csv/getintobed_ (6).csv', 'training_pca_csv/getintobed_ (7).csv', 'training_pca_csv/getintobed_ (8).csv', 'training_pca_csv/getintobed_ (9).csv', 'training_pca_csv/getintobed_ (10).csv', 'training_pca_csv/getintobed_ (11).csv', 'training_pca_csv/getintobed_ (12).csv', 'training_pca_csv/getintobed_ (13).csv', 'training_pca_csv/getintobed_ (14).csv', 'training_pca_csv/getintobed_ (15).csv', 'training_pca_csv/getintobed_ (16).csv', 'training_pca_csv/getintobed_ (17).csv', 'training_pca_csv/getintobed_ (18).csv', 'training_pca_csv/getintobed_ (19).csv', 'training_pca_csv/getintobed_ (20).csv', 'training_pca_csv/getintobed_ (21).csv', 'training_pca_csv/getintobed_ (22).csv', 'training_pca_csv/getintobed_ (23).csv', 'training_pca_csv/getintobed_ (24).csv', 'training_pca_csv/getintobed_ (25).csv']
#
#
#
# ['training_pca_csv/nothing_ (1).csv', 'training_pca_csv/nothing_ (2).csv', 'training_pca_csv/nothing_ (3).csv', 'training_pca_csv/nothing_ (4).csv', 'training_pca_csv/nothing_ (5).csv', 'training_pca_csv/nothing_ (6).csv', 'training_pca_csv/nothing_ (7).csv', 'training_pca_csv/nothing_ (8).csv', 'training_pca_csv/nothing_ (9).csv', 'training_pca_csv/nothing_ (10).csv', 'training_pca_csv/nothing_ (11).csv', 'training_pca_csv/nothing_ (12).csv', 'training_pca_csv/nothing_ (13).csv', 'training_pca_csv/nothing_ (14).csv', 'training_pca_csv/nothing_ (15).csv', 'training_pca_csv/nothing_ (16).csv', 'training_pca_csv/nothing_ (17).csv', 'training_pca_csv/nothing_ (18).csv', 'training_pca_csv/nothing_ (19).csv', 'training_pca_csv/nothing_ (20).csv', 'training_pca_csv/nothing_ (21).csv', 'training_pca_csv/nothing_ (22).csv', 'training_pca_csv/nothing_ (23).csv', 'training_pca_csv/nothing_ (24).csv', 'training_pca_csv/nothing_ (25).csv']
#
#
#
# ['training_pca_csv/sitdown_chair_ (1).csv', 'training_pca_csv/sitdown_chair_ (2).csv', 'training_pca_csv/sitdown_chair_ (3).csv', 'training_pca_csv/sitdown_chair_ (4).csv', 'training_pca_csv/sitdown_chair_ (5).csv', 'training_pca_csv/sitdown_chair_ (6).csv', 'training_pca_csv/sitdown_chair_ (7).csv', 'training_pca_csv/sitdown_chair_ (8).csv', 'training_pca_csv/sitdown_chair_ (9).csv', 'training_pca_csv/sitdown_chair_ (10).csv', 'training_pca_csv/sitdown_chair_ (11).csv', 'training_pca_csv/sitdown_chair_ (12).csv', 'training_pca_csv/sitdown_chair_ (13).csv', 'training_pca_csv/sitdown_chair_ (14).csv', 'training_pca_csv/sitdown_chair_ (15).csv', 'training_pca_csv/sitdown_chair_ (16).csv', 'training_pca_csv/sitdown_chair_ (17).csv', 'training_pca_csv/sitdown_chair_ (18).csv', 'training_pca_csv/sitdown_chair_ (19).csv', 'training_pca_csv/sitdown_chair_ (20).csv', 'training_pca_csv/sitdown_chair_ (21).csv', 'training_pca_csv/sitdown_chair_ (22).csv', 'training_pca_csv/sitdown_chair_ (23).csv', 'training_pca_csv/sitdown_chair_ (24).csv', 'training_pca_csv/sitdown_chair_ (25).csv']
#
#
#
# ['training_pca_csv/sitdown_sofa_ (1).csv', 'training_pca_csv/sitdown_sofa_ (2).csv', 'training_pca_csv/sitdown_sofa_ (3).csv', 'training_pca_csv/sitdown_sofa_ (4).csv', 'training_pca_csv/sitdown_sofa_ (5).csv', 'training_pca_csv/sitdown_sofa_ (6).csv', 'training_pca_csv/sitdown_sofa_ (7).csv', 'training_pca_csv/sitdown_sofa_ (8).csv', 'training_pca_csv/sitdown_sofa_ (9).csv', 'training_pca_csv/sitdown_sofa_ (10).csv', 'training_pca_csv/sitdown_sofa_ (11).csv', 'training_pca_csv/sitdown_sofa_ (12).csv', 'training_pca_csv/sitdown_sofa_ (13).csv', 'training_pca_csv/sitdown_sofa_ (14).csv', 'training_pca_csv/sitdown_sofa_ (15).csv', 'training_pca_csv/sitdown_sofa_ (16).csv', 'training_pca_csv/sitdown_sofa_ (17).csv', 'training_pca_csv/sitdown_sofa_ (18).csv', 'training_pca_csv/sitdown_sofa_ (19).csv', 'training_pca_csv/sitdown_sofa_ (20).csv', 'training_pca_csv/sitdown_sofa_ (21).csv', 'training_pca_csv/sitdown_sofa_ (22).csv', 'training_pca_csv/sitdown_sofa_ (23).csv', 'training_pca_csv/sitdown_sofa_ (24).csv', 'training_pca_csv/sitdown_sofa_ (25).csv']
#
#
#
# ['training_pca_csv/sleeping_ (1).csv', 'training_pca_csv/sleeping_ (2).csv', 'training_pca_csv/sleeping_ (3).csv', 'training_pca_csv/sleeping_ (4).csv', 'training_pca_csv/sleeping_ (5).csv', 'training_pca_csv/sleeping_ (6).csv', 'training_pca_csv/sleeping_ (7).csv', 'training_pca_csv/sleeping_ (8).csv', 'training_pca_csv/sleeping_ (9).csv', 'training_pca_csv/sleeping_ (10).csv', 'training_pca_csv/sleeping_ (11).csv', 'training_pca_csv/sleeping_ (12).csv', 'training_pca_csv/sleeping_ (13).csv', 'training_pca_csv/sleeping_ (14).csv', 'training_pca_csv/sleeping_ (15).csv', 'training_pca_csv/sleeping_ (16).csv', 'training_pca_csv/sleeping_ (17).csv', 'training_pca_csv/sleeping_ (18).csv', 'training_pca_csv/sleeping_ (19).csv', 'training_pca_csv/sleeping_ (20).csv', 'training_pca_csv/sleeping_ (21).csv', 'training_pca_csv/sleeping_ (22).csv', 'training_pca_csv/sleeping_ (23).csv', 'training_pca_csv/sleeping_ (24).csv', 'training_pca_csv/sleeping_ (25).csv']
#
#
#
# ['training_pca_csv/standup_chair_ (1).csv', 'training_pca_csv/standup_chair_ (2).csv', 'training_pca_csv/standup_chair_ (3).csv', 'training_pca_csv/standup_chair_ (4).csv', 'training_pca_csv/standup_chair_ (5).csv', 'training_pca_csv/standup_chair_ (6).csv', 'training_pca_csv/standup_chair_ (7).csv', 'training_pca_csv/standup_chair_ (8).csv', 'training_pca_csv/standup_chair_ (9).csv', 'training_pca_csv/standup_chair_ (10).csv', 'training_pca_csv/standup_chair_ (11).csv', 'training_pca_csv/standup_chair_ (12).csv', 'training_pca_csv/standup_chair_ (13).csv', 'training_pca_csv/standup_chair_ (14).csv', 'training_pca_csv/standup_chair_ (15).csv', 'training_pca_csv/standup_chair_ (16).csv', 'training_pca_csv/standup_chair_ (17).csv', 'training_pca_csv/standup_chair_ (18).csv', 'training_pca_csv/standup_chair_ (19).csv', 'training_pca_csv/standup_chair_ (20).csv', 'training_pca_csv/standup_chair_ (21).csv', 'training_pca_csv/standup_chair_ (22).csv', 'training_pca_csv/standup_chair_ (23).csv', 'training_pca_csv/standup_chair_ (24).csv', 'training_pca_csv/standup_chair_ (25).csv']
#
#
#
# ['training_pca_csv/standup_sofa_ (1).csv', 'training_pca_csv/standup_sofa_ (2).csv', 'training_pca_csv/standup_sofa_ (3).csv', 'training_pca_csv/standup_sofa_ (4).csv', 'training_pca_csv/standup_sofa_ (5).csv', 'training_pca_csv/standup_sofa_ (6).csv', 'training_pca_csv/standup_sofa_ (7).csv', 'training_pca_csv/standup_sofa_ (8).csv', 'training_pca_csv/standup_sofa_ (9).csv', 'training_pca_csv/standup_sofa_ (10).csv', 'training_pca_csv/standup_sofa_ (11).csv', 'training_pca_csv/standup_sofa_ (12).csv', 'training_pca_csv/standup_sofa_ (13).csv', 'training_pca_csv/standup_sofa_ (14).csv', 'training_pca_csv/standup_sofa_ (15).csv', 'training_pca_csv/standup_sofa_ (16).csv', 'training_pca_csv/standup_sofa_ (17).csv', 'training_pca_csv/standup_sofa_ (18).csv', 'training_pca_csv/standup_sofa_ (19).csv', 'training_pca_csv/standup_sofa_ (20).csv', 'training_pca_csv/standup_sofa_ (21).csv', 'training_pca_csv/standup_sofa_ (22).csv', 'training_pca_csv/standup_sofa_ (23).csv', 'training_pca_csv/standup_sofa_ (24).csv', 'training_pca_csv/standup_sofa_ (25).csv']
#
#
#
# ['training_pca_csv/walk_ (1).csv', 'training_pca_csv/walk_ (2).csv', 'training_pca_csv/walk_ (3).csv', 'training_pca_csv/walk_ (4).csv', 'training_pca_csv/walk_ (5).csv', 'training_pca_csv/walk_ (6).csv', 'training_pca_csv/walk_ (7).csv', 'training_pca_csv/walk_ (8).csv', 'training_pca_csv/walk_ (9).csv', 'training_pca_csv/walk_ (10).csv', 'training_pca_csv/walk_ (11).csv', 'training_pca_csv/walk_ (12).csv', 'training_pca_csv/walk_ (13).csv', 'training_pca_csv/walk_ (14).csv', 'training_pca_csv/walk_ (15).csv', 'training_pca_csv/walk_ (16).csv', 'training_pca_csv/walk_ (17).csv', 'training_pca_csv/walk_ (18).csv', 'training_pca_csv/walk_ (19).csv', 'training_pca_csv/walk_ (20).csv', 'training_pca_csv/walk_ (21).csv', 'training_pca_csv/walk_ (22).csv', 'training_pca_csv/walk_ (23).csv', 'training_pca_csv/walk_ (24).csv', 'training_pca_csv/walk_ (25).csv']
#
#
#
# ['training_pca_csv/washingdishes_ (1).csv', 'training_pca_csv/washingdishes_ (2).csv', 'training_pca_csv/washingdishes_ (3).csv', 'training_pca_csv/washingdishes_ (4).csv', 'training_pca_csv/washingdishes_ (5).csv', 'training_pca_csv/washingdishes_ (6).csv', 'training_pca_csv/washingdishes_ (7).csv', 'training_pca_csv/washingdishes_ (8).csv', 'training_pca_csv/washingdishes_ (9).csv', 'training_pca_csv/washingdishes_ (10).csv', 'training_pca_csv/washingdishes_ (11).csv', 'training_pca_csv/washingdishes_ (12).csv', 'training_pca_csv/washingdishes_ (13).csv', 'training_pca_csv/washingdishes_ (14).csv', 'training_pca_csv/washingdishes_ (15).csv', 'training_pca_csv/washingdishes_ (16).csv', 'training_pca_csv/washingdishes_ (17).csv', 'training_pca_csv/washingdishes_ (18).csv', 'training_pca_csv/washingdishes_ (19).csv', 'training_pca_csv/washingdishes_ (20).csv', 'training_pca_csv/washingdishes_ (21).csv', 'training_pca_csv/washingdishes_ (22).csv', 'training_pca_csv/washingdishes_ (23).csv', 'training_pca_csv/washingdishes_ (24).csv', 'training_pca_csv/washingdishes_ (25).csv']

# %%
def wavelets1():
    for i in train_pca_list:
        coef,freqs = pywt.cwt(i[0],np.arange(1,300),wavelet='morl')
        sns.heatmap(coef,cmap='jet_r', shading='gouraud')
        plt.show()
def wavelets2():
    for i in train_pca_list:
        for j in range(54):
            coef,freqs = pywt.cwt(i[j],np.arange(1,300),wavelet='morl')
            sns.heatmap(coef,cmap='jet_r', shading='gouraud')
            plt.show()
#wavelets1()
#wavelets2()
N = 7
L = 15
scales = [2 ** (n + (l / L)) for n in range(N) for l in range(L)]

df = pd.read_csv(f'training_pca_csv/{file} ({i+1}).csv')
coef,freqs = pywt.cwt(train_pca_list[2][2]['0'], np.arange(1, 200), wavelet='morl')
sns.heatmap(coef, cmap='jet', shading='gouraud')
plt.show()
