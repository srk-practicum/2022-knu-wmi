# %%
import matplotlib.pyplot as plt
import pandas as pd
from CSIKit.tools.batch_graph import BatchGraph
import seaborn as sns
import os

# %% [markdown]
# ## DotPlot

# %%
colors = ['yellow', 'blue', 'orange', 'black', 'purple', 'brown', 'green']
csv_folders = os.listdir("csv_folders")
# plt.figure(figsize=(8, 5))
for ind, folder in enumerate(csv_folders):
    files = os.listdir(f"csv_folders/{folder}")
    ctr = 1
    for file in files:
        length = len(pd.DataFrame(pd.read_csv(f"csv_folders/{folder}/{file}")))
        ctr += 1
        plt.scatter(length, ctr, color=colors[ind])
    plt.scatter(length, ctr, color=colors[ind],label=csv_folders[ind])
plt.legend()
plt.gca().set(xlim=(24, 350), ylim=(0, 20), xlabel='Packets', ylabel='Count')
plt.grid()

# %% [markdown]
# ## LinePlot (frame)

# %% [markdown]
# one line

# %%
csi_matrix = pd.DataFrame(pd.read_csv("csv_folders/falldown/output.csv"))
packet = csi_matrix.iloc[3]
packet.plot.line(legend=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 10 lines

# %%
for i in range(10):
    csi_matrix.iloc[i].plot.line()

# %% [markdown]
# ## Heatmap

# %%
bg = BatchGraph("csi_tests/walking_along/output.pcap")
bg.heatmap()

# %%
bg = BatchGraph("csi_tests/walking_along/output1.pcap")
bg.heatmap()

# %%
bg = BatchGraph("csi_tests/walking_along/output2.pcap")
bg.heatmap()

# %%
bg = BatchGraph("csi_tests/walking_along/output3.pcap")
bg.heatmap()

# %%
bg = BatchGraph("csi_tests/walking_along/output4.pcap")
bg.heatmap()

# %% [markdown]
# ## LinePlot (subcarrier )

# %% [markdown]
# one subcarrier

# %%
packet = csi_matrix['15']
packet.plot.line(legend=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 10 subcarriers

# %%
for i in range(10):
    csi_matrix[str(i+10)].plot.line()

# %%
csi_matrix = pd.DataFrame(pd.read_csv("csv_folders/walking_along/output.csv"))
correlation = csi_matrix.corr()
sns.heatmap(correlation)
# Out:
# <AxesSubplot:>
